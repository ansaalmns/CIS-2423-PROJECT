# %% [markdown]
# <a href="https://colab.research.google.com/github/ansaalmns/CIS-2423-PROJECT/blob/main/Multiple_Linear_Regression_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
#Load the dataset
df = pd.read_csv('Global_AI_Content_Impact_Dataset.csv')
df
# Out:
#          Country  Year    Industry  AI Adoption Rate (%)  \
# 0    South Korea  2022       Media                 44.29
# 1          China  2025       Legal                 34.75
# 2            USA  2022  Automotive                 81.06
# 3         France  2021       Legal                 85.24
# 4         France  2021      Gaming                 78.95
# ..           ...   ...         ...                   ...
# 195      Germany  2021  Automotive                 89.44
# 196      Germany  2020       Media                 70.11
# 197       France  2023   Marketing                 65.77
# 198    Australia  2023  Automotive                 45.35
# 199  South Korea  2020  Healthcare                 10.53
#
#      AI-Generated Content Volume (TBs per year)  Job Loss Due to AI (%)  \
# 0                                         33.09                   16.77
# 1                                         66.74                   46.89
# ...

# %%
df['Job Loss Due to AI (%)']
# Out:
# 0      16.77
# 1      46.89
# 2      10.66
# 3      27.70
# 4      17.45
#        ...
# 195    48.47
# 196    27.62
# 197    39.94
# 198    33.21
# 199    23.64
# Name: Job Loss Due to AI (%), Length: 200, dtype: float64

# %%
# select the indpeendent variable X=AI adoption rate, Human-AI Collaboration Rate, Consumer Trust in AI
# y=Job Loss Due to AI
X = df[['AI Adoption Rate (%)', 'Consumer Trust in AI (%)', 'Human-AI Collaboration Rate (%)']]
y = df['Job Loss Due to AI (%)']

# %%
#make predictions
predictions = model.predict(X)

# %%
# Split the dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)
print(X_train)
print(X_test)
print(y_train)
print(y_test)
# Out:
#      AI Adoption Rate (%)  Consumer Trust in AI (%)  \
# 62                  20.25                     80.65
# 30                  67.15                     48.10
# 193                 81.86                     31.33
# 163                 60.69                     30.81
# 123                 17.05                     83.17
# ..                    ...                       ...
# 136                 33.91                     76.05
# 165                 34.27                     87.03
# 48                  61.49                     87.90
# 94                  76.22                     74.86
# 23                  49.97                     78.71
#
#      Human-AI Collaboration Rate (%)
# 62                             80.08
# 30                             40.95
# 193                            63.48
# 163                            39.50
# 123                            79.54
# ..                               ...
# 136                            32.10
# ...

# %%
# Train the multiple linear regression model
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
##Predicting the test set results
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([23.86, 24.9 , 25.53, 25.55, 25.41, 24.84, 24.  , 25.29, 24.83,
#        25.83, 25.37, 24.34, 25.36, 24.45, 24.12, 23.97, 25.89, 25.75,
#        24.81, 24.72, 24.89, 24.54, 25.04, 25.68, 24.86, 24.69, 26.06,
#        25.65, 24.59, 24.92, 24.62, 25.65, 24.59, 24.66, 25.75, 24.39,
#        25.57, 24.51, 25.64, 24.77])

# %%
#Predicting a specific value
#Finding the Job Loss Due to AI(dependent variable) for AI adoption rate, Human-AI Collaboration Rate, Consumer Trust in AI
regressor.predict([[60, 75, 50]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([25.57])

# %%
#Getting the final multi linear regression equation
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [ 0.01  0.04 -0.  ]
# 22.356699800413175

# %%
#The linear equation is
#Job Loss = 22.356699800413175 + 0.01*(AI Adoption Rate) + 0.04*(Consumer Trust in AI) - 0.00*(Human-AI Collaboration Rate)
