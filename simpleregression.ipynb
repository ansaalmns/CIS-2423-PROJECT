# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Load the dataset
dataset = pd.read_csv('Global_AI_Content_Impact_Dataset.csv')

# %%
# Select indep and dep variables
X = df.loc[:, [ 'AI Adoption Rate (%)']].values

y = df.loc[:, 'Job Loss Due to AI (%)'].values

# %%
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

# %%
# Train the model
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict on test data
y_pred = regressor.predict(X_test)

# %%
# Plot training set
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.title('Job Loss vs AI Adoption Rate (Training Set)')
plt.xlabel('AI Adoption Rate')
plt.ylabel('Job Loss due to AI')
plt.show()

# %%
# Plot test set
plt.scatter(X_test, y_test, color='green')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.title('Job Loss vs AI Adoption Rate (Test Set)')
plt.xlabel('AI Adoption Rate')
plt.ylabel('Job Loss due to AI')
plt.show()
